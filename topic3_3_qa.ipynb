# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 基础图像 + 数据产生
x = range(1,50)
y = [ i*3+6 for i in x]
# Out:
# range(1, 50)

# %%
# y= []
# for i in x:
# #     print (i)
# #     print (i*3+6)
#     y.append(i*3+6)
# y

# %%
plt.plot(x,y)

# %%
x = [1,2,3]
y = [2,4,1]

# %%
plt.plot(x,y)
plt.title('this is a title')
plt.xlabel('x label')
plt.ylabel('y label')
# Out:
# Text(0, 0.5, 'y label')

# %%
test.txt
1 2
2 4
3 1

# %%
with open('test.txt') as f:
    data = f.read()
data2= data.split('\n')
data2
# Out:
# ['1 2', '2 4', '3 1']

# %%
data2[0].split(' ')
# Out:
# ['1', '2']

# %%
x = [row.split(' ')[0] for row in data2]
y = [int(row.split(' ')[1]) for row in data2]

# %%
x
# Out:
# ['1', '2', '3']

# %%
y
# Out:
# [2, 4, 1]

# %%
plt.plot(x,y)
plt.title('this is a title')
plt.xlabel('x label')
plt.ylabel('y label')
# Out:
# Text(0, 0.5, 'y label')

# %%
# 10-03-16,774.25,776.065002,769.5,772.559998
# 10-04-16,776.030029,778.710022,772.890015,776.429993
# 10-05-16,779.309998,782.070007,775.650024,776.469971
# 10-06-16,779,780.47998,775.539978,776.859985
# 10-07-16,779.659973,779.659973,770.75,775.080017

# %%
# df = pd.read_csv('f.csv',header=None)
df = pd.read_csv('f.csv',parse_dates=True,header=None, index_col=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5 entries, 2016-10-03 to 2016-10-07
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1       5 non-null      float64
#  1   2       5 non-null      float64
#  2   3       5 non-null      float64
#  3   4       5 non-null      float64
# dtypes: float64(4)
# memory usage: 200.0 bytes

# %%
df
# Out:
#                      1           2           3           4
# 0
# 2016-10-03  774.250000  776.065002  769.500000  772.559998
# 2016-10-04  776.030029  778.710022  772.890015  776.429993
# 2016-10-05  779.309998  782.070007  775.650024  776.469971
# 2016-10-06  779.000000  780.479980  775.539978  776.859985
# 2016-10-07  779.659973  779.659973  770.750000  775.080017

# %%
list1=['open','high','low','close']

# %%
df.columns = list1

# %%
df.head()
# Out:
#                   open        high         low       close
# 0
# 2016-10-03  774.250000  776.065002  769.500000  772.559998
# 2016-10-04  776.030029  778.710022  772.890015  776.429993
# 2016-10-05  779.309998  782.070007  775.650024  776.469971
# 2016-10-06  779.000000  780.479980  775.539978  776.859985
# 2016-10-07  779.659973  779.659973  770.750000  775.080017

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='0'>

# %%
# #  柱状图
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
x = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

# %%
y
# Out:
# [2, 4, 1]

# %%
for i, _ in enumerate(x):
    print (i,_)
# Out:
# 0 Java
# 1 Python
# 2 PHP
# 3 JavaScript
# 4 C#
# 5 C++

# %%
x_pos = [i for i, _ in enumerate(x)]
x_pos
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
plt.figure(figsize=(8,8))
plt.bar(x,popularity)
plt.plot(x,popularity,color='r')
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
# 增加一些位置信息
x_pos = [i for i, _ in enumerate(x)]
plt.xticks(x_pos, x)
plt.yticks
# Out:
# ([<matplotlib.axis.XTick at 0x24dcefebdc0>,
# ...
#  [Text(0, 0, 'Java'),
#   Text(1, 0, 'Python'),
#   Text(2, 0, 'PHP'),
#   Text(3, 0, 'JavaScript'),
#   Text(4, 0, 'C#'),
#   Text(5, 0, 'C++')])

# %%
plt.figure(figsize=(8,8))
plt.barh(x,popularity)
# plt.plot(x,popularity,color='r')
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
# 增加一些位置信息
x_pos = [i for i, _ in enumerate(x)]
# plt.xticks(x_pos, x)

# %%
plt.figure(figsize=(8,8))
plt.bar(x,popularity,color=['red', 'green', 'blue', 'yellow', 'cyan'])
# plt.plot(x,popularity,color='r')
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
# 增加一些位置信息
x_pos = [i for i, _ in enumerate(x)]
plt.xticks(x_pos, x)
# Out:
# ([<matplotlib.axis.XTick at 0x24dd1976fd0>,
# ...
#  [Text(0, 0, 'Java'),
#   Text(1, 0, 'Python'),
#   Text(2, 0, 'PHP'),
#   Text(3, 0, 'JavaScript'),
#   Text(4, 0, 'C#'),
#   Text(5, 0, 'C++')])

# %%
# 如果 在部分数据图表中 我们需要把数值也打到图上

# %%
plt.figure(figsize=(8,8))
fig,ax = plt.subplots()
# plt.bar(x,popularity,color=['red', 'green', 'blue', 'yellow', 'cyan'])
rects1 = ax.bar(x,popularity,color=['red', 'green', 'blue', 'yellow', 'cyan'])
# plt.plot(x,popularity,color='r')
plt.minorticks_on()
# plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
# plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
# 增加一些位置信息
x_pos = [i for i, _ in enumerate(x)]
plt.xticks(x_pos, x)
# ax.text(3,15,'aaaa')
# ax.text(3,18,'bbb')

def autolabel(l):
    for rect in l:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%f' % float(height),
        ha='center', va='bottom')
autolabel(rects1)

# %%
# 迭代器的使用和 普通列表的区别

# %%
mytuple = ("apple", "banana", "cherry")

# %%
for  i in mytuple:
    print (i)
# Out:
# apple
# banana
# cherry

# %%
myit = iter(mytuple)

# %%
next(myit)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-104-ec9104da3bd7> in <module>
# ----> 1 next(myit)
#
# StopIteration:

# %%
next(myit)
# Out:
# 'banana'

# %%
next(myit)
# Out:
# 'cherry'

# %%
# class MyNumbers:
#   def __iter__(self):
#     self.a = 1
#     return self

#   def __next__(self):
#     if self.a <= 20:
#       x = self.a
#       self.a += 1
#       return x
#     else:
#       raise StopIteration

# %%
import matplotlib.pyplot as plt
import numpy as np
import datetime
import matplotlib.dates as mdates
from matplotlib.ticker import AutoMinorLocator

fig, ax = plt.subplots(constrained_layout=True)
x = np.arange(0, 360, 1)
y = np.sin(2 * x * np.pi / 180)
ax.plot(x, y)
ax.set_xlabel('angle [degrees]')
ax.set_ylabel('signal')
ax.set_title('Sine wave')


def deg2rad(x):
    return x * np.pi / 180


def rad2deg(x):
    return x * 180 / np.pi

secax = ax.secondary_xaxis('top', functions=(deg2rad, rad2deg))
secax.set_xlabel('angle [rad]')
# Out:
# Text(0.5, 0, 'angle [rad]')

# %%
fig, ax = plt.subplots()
ax.plot(range(1, 360, 5), range(1, 360, 5))
ax.set_ylabel('degrees')
secax = ax.secondary_yaxis('right', functions=(np.deg2rad,
                                               np.rad2deg))
secax.set_ylabel('radians')
# Out:
# Text(0, 0.5, 'radians')
